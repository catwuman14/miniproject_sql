# %%
import pandas as pd
url = "/Users/catherinewu/Downloads/supermarket_sales - Sheet1.csv"
df_sup = pd.read_csv(url)

df_sup
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# URL
# CHECK REQUEST
#RESPONSE
#PARSE SOUP
#PRETTIFY - TO SEE THE SCRIPT 
#ROWS = need to do a for loop for each row
#DATA =

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.worldometers.info/world-population/myanmar-population/'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->
# <!--[if !IE]><!-->
# <html lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Myanmar Population (2025) - Worldometer
#   </title>
#   <meta content="Population of Myanmar: current, historical, and projected population, growth rate, immigration, median age, total fertility rate (TFR), population density, urbanization, urban population, country's share of world population, and global rank. Data tables, maps, charts, and live population clock" name="description"/>
#   <!-- Favicon -->
#   <link href="/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# ...

# %%
tbodies = soup.find_all("tbody")
tbodies
# Out:
# [<tbody> <tr> <td>2025</td> <td><strong>54,850,648</strong></td> <td>0.64 %</td> <td>350,557</td> <td>-39,661</td> <td>30.1</td> <td>2.08</td> <td>84</td> <td>34.1 %</td> <td>18,722,491</td> <td>0.67 %</td> <td>8,231,613,070</td> <td>27</td> </tr> <tr> <td>2024</td> <td><strong>54,500,091</strong></td> <td>0.68 %</td> <td>366,293</td> <td>-37,979</td> <td>29.8</td> <td>2.10</td> <td>83</td> <td>33.7 %</td> <td>18,372,626</td> <td>0.67 %</td> <td>8,161,972,572</td> <td>27</td> </tr> <tr> <td>2023</td> <td><strong>54,133,798</strong></td> <td>0.70 %</td> <td>377,011</td> <td>-34,989</td> <td>29.5</td> <td>2.12</td> <td>83</td> <td>33.3 %</td> <td>18,032,802</td> <td>0.67 %</td> <td>8,091,734,930</td> <td>27</td> </tr> <tr> <td>2022</td> <td><strong>53,756,787</strong></td> <td>0.69 %</td> <td>369,685</td> <td>-34,988</td> <td>29.3</td> <td>2.13</td> <td>82</td> <td>32.9 %</td> <td>17,702,521</td> <td>0.67 %</td> <td>8,021,407,192</td> <td>27</td> </tr> <tr> <td>2020</td> <td><strong>53
# ...

# %%
city_element = soup.find_all("td", style = "font-weight: bold; font-size:17px; text-align:left; padding-left:10px; padding-top:5px; padding-bottom:5px")
city_element
# Out:
# [<td style="font-weight: bold; font-size:17px; text-align:left; padding-left:10px; padding-top:5px; padding-bottom:5px">Yangon</td>,
#  <td style="font-weight: bold; font-size:17px; text-align:left; padding-left:10px; padding-top:5px; padding-bottom:5px">Mandalay</td>,
#  <td style="font-weight: bold; font-size:17px; text-align:left; padding-left:10px; padding-top:5px; padding-bottom:5px">Nay Pyi Taw</td>,
#  <td style="font-weight: bold; font-size:17px; text-align:left; padding-left:10px; padding-top:5px; padding-bottom:5px">Mawlamyine</td>,
#  <td style="font-weight: bold; font-size:17px; text-align:left; padding-left:10px; padding-top:5px; padding-bottom:5px">Kyain Seikgyi Township</td>,
#  <td style="font-weight: bold; font-size:17px; text-align:left; padding-left:10px; padding-top:5px; padding-bottom:5px">Bago</td>,
#  <td style="font-weight: bold; font-size:17px; text-align:left; padding-left:10px; padding-top:5px; padding-bottom:5px">Pathein</td>,
# ...

# %%
city = [i.get_text() for i in city_element]
city
# Out:
# ['Yangon',
#  'Mandalay',
#  'Nay Pyi Taw',
#  'Mawlamyine',
#  'Kyain Seikgyi Township',
#  'Bago',
#  'Pathein',
#  'Monywa',
#  'Sittwe',
#  'Meiktila',
#  'Myeik',
#  'Keng Tung',
#  'Taunggyi',
#  'Myingyan',
#  'Dawei',
#  'Pyay',
#  'Hinthada',
#  'Lashio',
#  'Pakokku',
#  'Thaton',
#  'Pyin Oo Lwin',
#  'Yenangyaung',
#  'Taungoo',
#  'Thayetmyo',
#  'Pyinmana',
#  'Magway',
#  'Myitkyina',
#  'Chauk',
#  'Mogok',
#  'Nyaunglebin',
#  'Mudon',
#  'Shwebo',
#  'Sagaing',
#  'Taungdwingyi',
#  'Syriam',
#  'Bogale',
#  'Pyapon',
#  'Yamethin',
#  'Kanbe',
#  'Kawthoung',
#  'Myaydo',
#  'Minbu',
#  'Tharyarwady',
#  'Thongwa',
#  'Kyaiklat',
#  'Tachilek',
#  'Maubin',
#  'Kyaukse',
#  'Hpa-An',
#  'Kyaikto',
#  'Martaban',
#  'Kyaikkami',
#  'Bhamo',
#  'Twante',
#  'Myawadi',
#  'Mawlaik',
#  'Wakema',
#  'Myanaung',
#  'Pyu',
#  'Kayan',
#  'Nyaungdon',
#  'Mawlamyinegyunn',
#  'Letpandan',
#  'Thanatpin',
#  'Paungde',
#  'Hakha',
#  'Loikaw']

# %%
city_population = soup.find_all("td", style = " font-size:17px; text-align:left; padding-left:10px; padding-top:5px; padding-bottom:5px")
population = [i.getText() for i in city_population]
population
# Out:
# ['4,477,638',
#  '1,208,099',
#  '925,000',
#  '438,861',
#  '246,065',
#  '244,376',
#  '237,089',
#  '182,011',
#  '177,743',
#  '177,442',
#  '173,298',
#  '171,620',
#  '160,115',
#  '141,713',
#  '136,783',
#  '135,308',
#  '134,947',
#  '131,016',
#  '126,938',
#  '123,727',
#  '117,303',
#  '110,553',
#  '106,945',
#  '98,185',
#  '97,409',
#  '96,954',
#  '90,894',
#  '90,870',
#  '90,843',
#  '89,626',
#  '89,123',
#  '88,914',
#  '78,739',
#  '70,094',
#  '69,448',
#  '68,938',
#  '65,601',
#  '59,867',
#  '58,146',
#  '57,949',
#  '57,897',
#  '57,342',
#  '54,386',
#  '52,496',
#  '52,425',
#  '51,553',
#  '51,542',
#  '50,480',
#  '50,000',
#  '48,658',
#  '48,629',
#  '48,100',
#  '47,920',
#  '46,516',
#  '45,000',
#  '44,540',
#  '42,705',
#  '42,252',
#  '40,386',
#  '40,322',
#  '40,092',
#  '39,115',
#  '38,936',
#  '38,059',
#  '36,971',
#  '20,000',
#  '17,293']

# %%
df = pd.DataFrame ({"City":city, "Population":population})
df
# Out:
#                       City Population
# 0                   Yangon  4,477,638
# 1                 Mandalay  1,208,099
# 2              Nay Pyi Taw    925,000
# 3               Mawlamyine    438,861
# 4   Kyain Seikgyi Township    246,065
# ..                     ...        ...
# 62               Letpandan     38,936
# 63               Thanatpin     38,059
# 64                 Paungde     36,971
# 65                   Hakha     20,000
# 66                  Loikaw     17,293
#
# [67 rows x 2 columns]

# %%
df.dtypes
# Out:
# City          object
# Population    object
# dtype: object

# %%
df['Population'] = df['Population'].map(lambda x: x.replace(',', ''))

# %%
df['Population'] = df['Population'].apply(int)

# %%
df.dtypes
# Out:
# City          object
# Population     int64
# dtype: object

# %%
df.to_csv('/Users/catherinewu/Downloads/myanmarpop.csv')

# %%
df_sup
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df_sup['Invoice ID'] = df_sup['Invoice ID'].map(lambda x: x.replace('-', ''))

# %%
df_sup.drop(columns = ['Date', 'gross margin percentage'], inplace= True)

# %%
df_sup.dtypes
# Out:
# Invoice ID        object
# Branch            object
# City              object
# Customer type     object
# Gender            object
# Product line      object
# Unit price       float64
# Quantity           int64
# Tax 5%           float64
# Total            float64
# Time              object
# Payment           object
# cogs             float64
# gross income     float64
# Rating           float64
# dtype: object

# %%
df_sup.drop(columns = ['Unit price'], inplace= True)

# %%
df_sup['City']= df_sup['City'].map(lambda x:"Nay Pyi Taw" if x == "Naypyitaw" else x)

# %%
df_sup
# Out:
#     Invoice ID Branch         City Customer type  Gender  \
# 0    750678428      A       Yangon        Member  Female
# 1    226313081      C  Nay Pyi Taw        Normal  Female
# 2    631413108      A       Yangon        Normal    Male
# 3    123191176      A       Yangon        Member    Male
# 4    373737910      A       Yangon        Normal    Male
# ..         ...    ...          ...           ...     ...
# 995  233675758      C  Nay Pyi Taw        Normal    Male
# 996  303962227      B     Mandalay        Normal  Female
# 997  727021313      A       Yangon        Member    Male
# 998  347562442      A       Yangon        Normal    Male
# 999  849093807      A       Yangon        Member  Female
#
#                Product line  Quantity   Tax 5%      Total   Time      Payment  \
# 0         Health and beauty         7  26.1415   548.9715  13:08      Ewallet
# 1    Electronic accessories         5   3.8200    80.2200  10:29         Cash
# ...

# %%
df_sup.to_csv('/Users/catherinewu/Downloads/sup.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = "payment_type_city (1).csv"
df = pd.read_csv(file_path)

# Display column names for verification
print("Columns in CSV:", df.columns)

# Automatically handle column names if different
expected_columns = ["city", "payment_type", "count"]
if len(df.columns) != len(expected_columns):
    df.columns = df.columns[:len(expected_columns)]

df.columns = expected_columns

# Aggregate the count data by payment type
overall_data = df.groupby("payment_type")[["count"]].sum().reset_index()

# Generate a single pie chart for overall payment type distribution
plt.figure(figsize=(8, 8))
plt.pie(overall_data["count"], labels=overall_data["payment_type"], autopct='%1.1f%%', startangle=140)
plt.title("Overall Payment Type Distribution")

plt.show()
# Out:
# Columns in CSV: Index(['city', 'payment', 'percentage_of_total'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = "payment_type_city (1).csv"
df = pd.read_csv(file_path)

# Display column names for verification
print("Columns in CSV:", df.columns)

# Automatically handle column names if different
expected_columns = ["city", "payment_type", "count"]
if len(df.columns) != len(expected_columns):
    df.columns = df.columns[:len(expected_columns)]

df.columns = expected_columns

# Get unique cities
cities = df["city"].unique()

# Create subplots
fig, axes = plt.subplots(1, len(cities), figsize=(15, 5))

# Ensure we handle cases where there's only one city
if len(cities) == 1:
    axes = [axes]

# Generate a pie chart for each city
for ax, city in zip(axes, cities):
    city_data = df[df["city"] == city]
    ax.pie(city_data["count"], labels=city_data["payment_type"], autopct='%1.1f%%', startangle=140)
    ax.set_title(f"Payment Type Distribution in {city}")

plt.tight_layout()
plt.show()
# Out:
# Columns in CSV: Index(['city', 'payment', 'percentage_of_total'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Create the DataFrame
data = {
    ‘city’: [‘Mandalay’, ‘Mandalay’, ‘Mandalay’, ‘Nay Pyi Taw’, ‘Nay Pyi Taw’, ‘Nay Pyi Taw’, ‘Yangon’, ‘Yangon’, ‘Yangon’],
    ‘payment’: [‘Cash’, ‘Credit card’, ‘Ewallet’, ‘Cash’, ‘Credit card’, ‘Ewallet’, ‘Cash’, ‘Credit card’, ‘Ewallet’],
    ‘total_spend’: [35337, 37349, 33513, 43085, 30326, 37158, 33780, 33097, 39325],
    ‘percentage_of_total’: [33.2743, 35.1689, 31.5568, 38.9666, 27.4272, 33.6062, 31.8073, 31.1642, 37.0285]
}
df = pd.DataFrame(data)
# Pivot the data to get ‘total_spend’ as columns for each payment method
pivot_df = df.pivot(index=‘city’, columns=‘payment’, values=‘total_spend’)
# Plotting the bar chart
pivot_df.plot(kind=‘bar’, stacked=False, figsize=(10, 6), color=[‘#1F77B4’, ‘#FF7F0E’, ‘#2CA02C’])
plt.title(‘Total Spend by City and Payment Method’)
plt.xlabel(‘City’)
plt.ylabel(‘Total Spend’)
plt.xticks(rotation=45)
plt.legend(title=‘Payment Method’)
plt.tight_layout()
# Show the plot
plt.show()
# Out:
#   Cell In[60], line 5
#     ‘city’: [‘Mandalay’, ‘Mandalay’, ‘Mandalay’, ‘Nay Pyi Taw’, ‘Nay Pyi Taw’, ‘Nay Pyi Taw’, ‘Yangon’, ‘Yangon’, ‘Yangon’],
#     ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Count the occurrences of each customer type
membership_counts = df_sup['Customer type'].value_counts()

# Create the bar plot
sns.barplot(x=membership_counts.index, y=membership_counts.values)

# Set labels and title
plt.xlabel('Customer Type')
plt.ylabel('Count')
plt.title('Count of Customer Types')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the DataFrame
data = {
    'city': ['Mandalay', 'Mandalay', 'Mandalay', 'Nay Pyi Taw', 'Nay Pyi Taw', 'Nay Pyi Taw', 'Yangon', 'Yangon', 'Yangon'],
    'payment': ['Cash', 'Credit card', 'Ewallet', 'Cash', 'Credit card', 'Ewallet', 'Cash', 'Credit card', 'Ewallet'],
    'total_spend': [35337, 37349, 33513, 43085, 30326, 37158, 33780, 33097, 39325],
    'percentage_of_total': [33.2743, 35.1689, 31.5568, 38.9666, 27.4272, 33.6062, 31.8073, 31.1642, 37.0285]
}

df = pd.DataFrame(data)

# Pivot the data to get 'total_spend' as columns for each payment method
pivot_df = df.pivot(index='city', columns='payment', values='total_spend')

# Plotting the bar chart
pivot_df.plot(kind='bar', stacked=False, figsize=(10, 6), color=['#1F77B4', '#FF7F0E', '#2CA02C'])
plt.title('Total Spend by City and Payment Method')
plt.xlabel('City')
plt.ylabel('Total Spend')
plt.xticks(rotation=45)
plt.legend(title='Payment Method')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file
file_path = "product_lines_gender.csv"
df = pd.read_csv(file_path)

# Rename columns for easier access
df.columns = ["product_line", "customer_type", "gender", "total_spend"]

# Split data into members and normal shoppers
df_members = df[df["customer_type"] == "Member"]
df_normal = df[df["customer_type"] == "Normal"]

# Pivot the data for better visualization
df_pivot_members = df_members.pivot(index="product_line", columns="gender", values="total_spend")
df_pivot_normal = df_normal.pivot(index="product_line", columns="gender", values="total_spend")

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Plot Members data
df_pivot_members.plot(kind="bar", width=0.8, ax=axes[0])
axes[0].set_title("Spend by Gender for Members")
axes[0].set_xlabel("Product Line")
axes[0].set_ylabel("Total Spend")
axes[0].tick_params(axis='x', rotation=45)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Plot Normal shoppers data
df_pivot_normal.plot(kind="bar", width=0.8, ax=axes[1])
axes[1].set_title("Spend by Gender for Normal Shoppers")
axes[1].set_xlabel("Product Line")
axes[1].tick_params(axis='x', rotation=45)
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
